# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %pip install seaborn
import seaborn as sns
# Out:
# Requirement already satisfied: seaborn in c:\users\vladv\anaconda3\lib\site-packages (0.11.2)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\vladv\anaconda3\lib\site-packages (from seaborn) (3.5.0)
# Requirement already satisfied: pandas>=0.23 in c:\users\vladv\anaconda3\lib\site-packages (from seaborn) (1.3.3)
# Requirement already satisfied: scipy>=1.0 in c:\users\vladv\anaconda3\lib\site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: numpy>=1.15 in c:\users\vladv\anaconda3\lib\site-packages (from seaborn) (1.20.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\vladv\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\vladv\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vladv\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vladv\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\vladv\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\vladv\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\vladv\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\vladv\anaconda3\lib\site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\vladv\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8252/2651919517.py in <module>
#       3 import matplotlib.pyplot as plt
#       4 get_ipython().run_line_magic('pip', 'install seaborn')
# ----> 5 import seaborn as sns
#
# ~\anaconda3\lib\site-packages\seaborn\__init__.py in <module>
#       1 # Import seaborn objects
# ----> 2 from .rcmod import *  # noqa: F401,F403
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
#       5 from .relational import *  # noqa: F401,F403
#
# ~\anaconda3\lib\site-packages\seaborn\rcmod.py in <module>
#       5 import matplotlib as mpl
#       6 from cycler import cycler
# ----> 7 from . import palettes
#       8
#       9
#
# ~\anaconda3\lib\site-packages\seaborn\palettes.py in <module>
#       7 from .external import husl
#       8
# ----> 9 from .utils import desaturate, get_color_cycle
#      10 from .colors import xkcd_rgb, crayons
#      11
#
# ~\anaconda3\lib\site-packages\seaborn\utils.py in <module>
#       8
#       9 import numpy as np
# ---> 10 from scipy import stats
#      11 import pandas as pd
#      12 import matplotlib as mpl
#
# ~\anaconda3\lib\site-packages\scipy\stats\__init__.py in <module>
#     439 """
#     440
# --> 441 from .stats import *
#     442 from .distributions import *
#     443 from .morestats import *
#
# ~\anaconda3\lib\site-packages\scipy\stats\stats.py in <module>
#      41 import scipy.special as special
#      42 from scipy import linalg
# ---> 43 from . import distributions
#      44 from . import mstats_basic
#      45 from ._stats_mstats_common import (_find_repeats, linregress, theilslopes,
#
# ~\anaconda3\lib\site-packages\scipy\stats\distributions.py in <module>
#       6 #       instead of `git blame -Lxxx,+x`.
#       7 #
# ----> 8 from ._distn_infrastructure import (rv_discrete, rv_continuous, rv_frozen)
#       9
#      10 from . import _continuous_distns
#
# ~\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py in <module>
#      22 # for root finding for continuous distribution ppf, and max likelihood
#      23 # estimation
# ---> 24 from scipy import optimize
#      25
#      26 # for functions of continuous distributions (e.g. moments, entropy, cdf)
#
# ~\anaconda3\lib\site-packages\scipy\optimize\__init__.py in <module>
#     398 """
#     399
# --> 400 from .optimize import *
#     401 from ._minimize import *
#     402 from ._root import *
#
# ~\anaconda3\lib\site-packages\scipy\optimize\optimize.py in <module>
#      34                          line_search_wolfe2 as line_search,
#      35                          LineSearchWarning)
# ---> 36 from ._numdiff import approx_derivative
#      37 from scipy._lib._util import getfullargspec_no_self as _getfullargspec
#      38 from scipy._lib._util import MapWrapper
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_numdiff.py in <module>
#       4 from numpy.linalg import norm
#       5
# ----> 6 from scipy.sparse.linalg import LinearOperator
#       7 from ..sparse import issparse, csc_matrix, csr_matrix, coo_matrix, find
#       8 from ._group_columns import group_dense, group_sparse
#
# ~\anaconda3\lib\site-packages\scipy\sparse\linalg\__init__.py in <module>
#     112 from .dsolve import *
#     113 from .interface import *
# --> 114 from .eigen import *
#     115 from .matfuncs import *
#     116 from ._onenormest import *
#
# ~\anaconda3\lib\site-packages\scipy\sparse\linalg\eigen\__init__.py in <module>
#       7
#       8 """
# ----> 9 from .arpack import *
#      10 from .lobpcg import *
#      11
#
# ~\anaconda3\lib\site-packages\scipy\sparse\linalg\eigen\arpack\__init__.py in <module>
#      18
#      19 """
# ---> 20 from .arpack import *
#
# ~\anaconda3\lib\site-packages\scipy\sparse\linalg\eigen\arpack\arpack.py in <module>
#      40 __all__ = ['eigs', 'eigsh', 'svds', 'ArpackError', 'ArpackNoConvergence']
#      41
# ---> 42 from . import _arpack
#      43 arpack_int = _arpack.timing.nbx.dtype
#      44
#
# ImportError: DLL load failed while importing _arpack: Не найдена указанная процедура.

# %%
data = pd.read_excel('C:\\Users\\vladv\\Desktop\\Study\\Горный\\2 курс\\1 семестр\\ЭСвОУ\\Курсовая\\Данные\\one_well_test.xlsx')

# %%
data.head()
# Out:
#         date  hours_online   WHT_degC     WHP_bar   DHT_degC     DHP_bar  \
# 0 2001-04-08           6.0  50.833367  113.969772  95.173012  150.926854
# 1 2001-04-09           0.0   7.873600    1.013526  92.106600   39.609044
# 2 2001-04-10           0.0   7.873600    1.013526  92.106600   38.223179
# 3 2001-04-11           0.0   7.873600    1.013526  92.106600   43.788237
# 4 2001-04-12           0.0   7.873600    1.013526  92.106600   44.234532
#
#    platform_choke_perc  oil_m3  gas_m3  produced_water_m3
# 0                  NaN     0.0     0.0           5.977039
# 1                  NaN     0.0     0.0           0.000000
# 2                  NaN     0.0     0.0           0.000000
# 3                  NaN     0.0     0.0           0.000000
# 4                  NaN     0.0     0.0           0.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6922 entries, 0 to 6921
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date                 6922 non-null   datetime64[ns]
#  1   hours_online         6905 non-null   float64
#  2   WHT_degC             6837 non-null   float64
#  3   WHP_bar              6034 non-null   float64
#  4   DHT_degC             6723 non-null   float64
#  5   DHP_bar              6712 non-null   float64
#  6   platform_choke_perc  1835 non-null   float64
#  7   oil_m3               6905 non-null   float64
#  8   gas_m3               6905 non-null   float64
#  9   produced_water_m3    6905 non-null   float64
# dtypes: datetime64[ns](1), float64(9)
# memory usage: 540.9 KB

# %%
data["oil_m3"].mean()
# Out:
# 150.55720804468967

# %%
nan_features = {}
for col in data.columns:
    nan_features[col] = data[col].isna().sum()
nan_features = pd.DataFrame(index=nan_features.keys(), columns=['na_count'], data=nan_features.values())

# %%
nan_features['percent of all data'] = round(nan_features['na_count']/data.shape[0] * 100, 2)

# %%
nan_features
# Out:
#                      na_count  percent of all data
# date                        0                 0.00
# hours_online               17                 0.25
# WHT_degC                   85                 1.23
# WHP_bar                   888                12.83
# DHT_degC                  199                 2.87
# DHP_bar                   210                 3.03
# platform_choke_perc      5087                73.49
# oil_m3                     17                 0.25
# gas_m3                     17                 0.25
# produced_water_m3          17                 0.25

# %%
data = data[data['produced_water_m3'] >= 0]

# %%
data.shape
# Out:
# (6888, 10)

# %%
plt.figure(figsize=(7,5), dpi=80)
sns.heatmap(data.drop('hours_online', axis=1).corr(), cmap='viridis', annot=True);
# plt.xticks(rotation=60)

# %%
markers = ['oil_m3', 'gas_m3', 'produced_water_m3']
features = data.drop(['oil_m3', 'gas_m3', 'produced_water_m3'], axis=1).columns

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(7,5), dpi=80)
ax2 = ax1.twinx()
lns2 = ax1.plot(data['date'], data['produced_water_m3'].rolling(4, min_periods=1).mean(), color='tab:blue', label='Вода')
lns1 = ax2.plot(data['date'], data['oil_m3'].rolling(4, min_periods=1).mean(), color='tab:orange', label='Нефть')
ax1.set_xlabel('Дата')
ax1.set_ylabel('Добыча нефти, $м^3$')
ax2.set_ylabel('Добыча воды, $м^3$')
ax1.grid()
lns = lns1 + lns2
labels = [i.get_label() for i in lns]
ax1.legend(lns, labels, loc='best')

fig, ax1 = plt.subplots(1, 1, figsize=(7,5), dpi=80)
ax2 = ax1.twinx()
lns2 = ax2.plot(data['date'], data['oil_m3'].rolling(4, min_periods=1).mean(), color='tab:orange', label='Нефть')
lns1 = ax1.plot(data['date'], data['gas_m3'].rolling(4, min_periods=1).mean()/1000, color='tab:green', label='Газ')
ax1.set_xlabel('Дата')
ax1.set_ylabel('Добыча газа, $тыс. м^3$')
ax2.set_ylabel('Добыча нефти, $м^3$')
ax1.grid()
lns = lns1 + lns2
labels = [i.get_label() for i in lns]
ax1.legend(lns, labels, loc='best')

fig, ax1 = plt.subplots(1, 1, figsize=(7,5), dpi=80)
ax2 = ax1.twinx()
lns2 = ax2.plot(data['date'], data['produced_water_m3'].rolling(4, min_periods=1).mean(), color='tab:blue', label='Вода')
lns1 = ax1.plot(data['date'], data['gas_m3'].rolling(4, min_periods=1).mean()/1000, color='tab:green', label='Газ')
ax1.set_xlabel('Дата')
ax1.set_ylabel('Добыча газа, $тыс. м^3$')
ax2.set_ylabel('Добыча воды, $м^3$')
ax1.grid()
lns = lns1 + lns2
labels = [i.get_label() for i in lns]
ax1.legend(lns, labels, loc='best')

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(7,5), dpi=80)
ax2 = ax1.twinx()
lns2 = ax2.plot(data['date'], data['DHP_bar'].rolling(4, min_periods=1).mean()/10, color='tab:grey', label='Забойное давление')
lns1 = ax1.plot(data['date'], data['gas_m3'].rolling(4, min_periods=1).mean()/1000, color='tab:green', label='Газ')
ax1.set_xlabel('Дата')
ax1.set_ylabel('Добыча добыча газа, $тыс. м^3$')
ax2.set_ylabel('Давление, $МПа$')
ax1.grid()
lns = lns1 + lns2
labels = [i.get_label() for i in lns]
ax1.legend(lns, labels, loc='best')

# %%
plt.figure(figsize=(7,5))
plt.plot(data['date'], data['DHP_bar'].rolling(4, min_periods=1).mean()/10, label='Забойное давление')
plt.plot(data['date'], data['WHP_bar'].rolling(4, min_periods=1).mean()/10, label='Устьевое давление')
plt.xlabel('Дата')
plt.ylabel('Давление, $МПа$')
plt.legend(loc='best')
plt.grid()

# %%
data["DHP_bar"].min()
# Out:
# 0.0

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(7,5), dpi=80)
ax2 = ax1.twinx()
lns2 = ax2.plot(data[data['date'] > '2019']['date'], data[data['date'] > '2019']['WHT_degC'].rolling(4, min_periods=1).mean(), color='tab:green', label='WHT')
lns1 = ax1.plot(data[data['date'] > '2019']['date'], data[data['date'] > '2019']['oil_m3'].rolling(4, min_periods=1).mean(), color='tab:orange', label='Oil')
ax1.set_xlabel('Year')
ax1.set_ylabel('Oil Production, m3')
ax2.set_ylabel('Wellhead Temperature, degC')
ax1.grid()
lns = lns1 + lns2
labels = [i.get_label() for i in lns]
ax1.legend(lns, labels, loc='best')
for tick in ax1.get_xticklabels():
    tick.set_rotation(45)

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(7,5), dpi=80)
ax2 = ax1.twinx()
lns2 = ax2.plot(data['date'], data['DHT_degC'].rolling(4, min_periods=1).mean(), color='tab:grey', label='DHT')
lns1 = ax1.plot(data['date'], data['produced_water_m3'].rolling(4, min_periods=1).mean(), color='tab:green', label='Water')
ax1.set_xlabel('Year')
ax1.set_ylabel('Water Production, m3')
ax2.set_ylabel('Downhole Temperature, degC')
ax1.grid()
lns = lns1 + lns2
labels = [i.get_label() for i in lns]
ax1.legend(lns, labels, loc='center left')

# %%
plt.plot(data['date'], data['platform_choke_perc'])

# %%
ig, ax1 = plt.subplots(1, 1, figsize=(7,5), dpi=80)
ax2 = ax1.twinx()
lns2 = ax2.plot(data[data['produced_water_m3'] < 500]['date'], data[data['produced_water_m3'] < 500]['oil_m3'].rolling(4, min_periods=1).mean(), color='tab:orange', label='Oil')
lns1 = ax1.plot(data[data['produced_water_m3'] < 500]['date'], data[data['produced_water_m3'] < 500]['produced_water_m3'].rolling(4, min_periods=1).mean(), color='tab:blue', label='Water')
ax1.set_xlabel('Date')
ax1.set_ylabel('Water Production')
ax2.set_ylabel('Oil Production')
ax1.grid()
lns = lns1 + lns2
labels = [i.get_label() for i in lns]
ax1.legend(lns, labels, loc='best')

# %%
plt.plot(data[data['date'] > '2008']['date'], data[data['date'] > '2008']['oil_m3'])

# %%
for i in data.columns:
    print('Nonzero numbers of ' + i + ': ', np.count_nonzero(data[i].fillna(0)))
# Out:
# Nonzero numbers of date:  6888
# Nonzero numbers of hours_online:  4778
# Nonzero numbers of WHT_degC:  5127
# Nonzero numbers of WHP_bar:  3695
# Nonzero numbers of DHT_degC:  4340
# Nonzero numbers of DHP_bar:  5060
# Nonzero numbers of platform_choke_perc:  1787
# Nonzero numbers of oil_m3:  4248
# Nonzero numbers of gas_m3:  4224
# Nonzero numbers of produced_water_m3:  3260

# %% [markdown]
# Нужно правильно избавиться от нулевых значений штуцера и разделить датасеты

# %%
np.count_nonzero(data['hours_online'])
# Out:
# 4778

# %%
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler

# %%
s_scaler = StandardScaler()
tsne = TSNE(random_state=17)
scaled_data = s_scaler.fit_transform(data.drop('date', axis=1).fillna(0))
tsne_repr = tsne.fit_transform(scaled_data)
plt.scatter(tsne_repr[:, 0], tsne_repr[:, 1])

# %%
def nonzero_data(df):

    df = df[df['produced_water_m3'] < 500]
    # df = df[df['date'] > '2006']
    df = df.drop('date', axis=1)
    df = df.fillna(0)
    
    #for i in df.columns:
    #    if i != 'platform_choke_perc' and i != 'date':
    #        df[i] = df[i].replace(0, np.nan)
    #        df = df[df[i] >= 0]
    #        df = df.dropna(subset=[i])
    return df

# %%
df_choke = nonzero_data(data)

# %%
df_choke.reset_index(inplace=True)

# %%
df_choke.drop('index', axis=1, inplace=True)

# %% [markdown]
# # Прототипы

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb

# %%
from sklearn.decomposition import PCA
from sklearn.cluster import DBSCAN

# %%
X, y = df_choke.drop(['oil_m3', 'gas_m3', 'produced_water_m3', 'hours_online'], axis=1), np.array(df_choke['produced_water_m3'].values).reshape(-1,)

# %%
y_all = df_choke[['oil_m3', 'gas_m3', 'produced_water_m3']]

# %%
y_all.shape, X.shape
# Out:
# ((6885, 3), (6885, 5))

# %%
def clean_data(X):
    from sklearn.decomposition import PCA
    from sklearn.cluster import DBSCAN

    scaler = MinMaxScaler()
    pca = PCA()
    
    X_scaled = scaler.fit_transform(X)
    X_pca = pca.fit_transform(X_scaled)
    pca_df = pd.DataFrame(X_pca)
    
    clustering = DBSCAN(eps=0.5, min_samples=12).fit(X_pca)
    pca_df['DBSCAN'] = clustering.labels_ + 1
    clust_df = pca_df[pca_df['DBSCAN'] == 1]
    clust_df.drop('DBSCAN', axis=1, inplace=True)

    return clust_df.index

# %%
scaler = MinMaxScaler()
pca = PCA()

# %%
X_scaled = scaler.fit_transform(X)

# %%
X_pca = pca.fit_transform(X_scaled)
pca_df = pd.DataFrame(X_pca)

# %%
clustering = DBSCAN(eps=0.5, min_samples=12).fit(X_pca)

# %%
pca_df['DBSCAN'] = clustering.labels_ + 1

# %%
clust_df = pca_df[pca_df['DBSCAN'] == 1]

# %%
clust_df.drop('DBSCAN', axis=1, inplace=True)
# Out:
# C:\Users\vladv\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
#X_merge = X.merge(pca_df, left_index=True, right_index=True)
#X_merge['labeled_y'] = y

# %%
X.iloc[clust_df.index.tolist(), :].shape, X.shape
# Out:
# ((6840, 5), (6885, 5))

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X.iloc[clust_df.index.tolist(), :], y[clust_df.index.tolist()], shuffle=True, random_state=17, test_size=.3
)
#X_train, X_test, y_train, y_test = X.iloc[:800], X.iloc[801:], y.iloc[:800], y.iloc[801:]

# %%
plt.plot(df_choke.iloc[clust_df.index.tolist(), 6])

# %%
X.iloc[clust_df.index.tolist(), :].shape, X.shape
# Out:
# ((6840, 5), (6885, 5))

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
mean_absolute_error(y_test, lr.predict(X_test)), r2_score(y_test, lr.predict(X_test))
# Out:
# (101.62894439683085, 0.3781771694191519)

# %%
rf = RandomForestRegressor(random_state=17)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=17)

# %%
rf_preds = rf.predict(X_test)

# %% [markdown]
# ## RF metrics

# %%
mean_absolute_error(y_test, rf_preds), r2_score(y_test, rf_preds)
# Out:
# (34.84670051622474, 0.8993357234722654)

# %% [markdown]
# ## Усложнение моделей

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
# rf_params = {'n_estimators': np.arange(100, 2000, 20)
#             , 'max_depth': [12, 13]
#             , 'min_samples_split': [2, 5, 8]}

# %%
# search_rf = RandomizedSearchCV(rf, rf_params, n_jobs=-1, cv=3, scoring='neg_mean_squared_error')

# %%
# search_rf.fit(X_train, y_train)

# %%
# search_rf.best_params_

# %%
# best_rf = search_rf.best_estimator_

# %%
# best_rf.fit(X_train, y_train)

# %%
# best_rf_pred = best_rf.predict(X_test)

# %%
# pd.DataFrame({'feature': X.columns, 'Importance': best_rf.feature_importances_}).sort_values(by='Importance', ascending=False)

# %%
# mean_absolute_error(y_test, best_rf_pred), r2_score(y_test, best_rf_pred)
# Out:
# (9.68252037200339, 0.6376622800242744)

# %%
xgboost = xgb.XGBRegressor()

# %%
from hyperopt import STATUS_OK, Trials, fmin, hp, tpe

# %%
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)
params = {'learning_rate': 0.01, 'max_depth': 10}
model = xgb.train(params, dtrain, 60)
predictions = model.predict(dtest)

# %%
mean_absolute_error(y_test, predictions), r2_score(y_test, predictions)
# Out:
# (88.77172245328347, 0.4601996221558705)

# %%
def score(params):
    print('Params:')
    print(params)
    params['max_depth'] = int(params['max_depth'])
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dtest = xgb.DMatrix(X_test, label=y_test)
    model = xgb.train(params, dtrain, params['num_round'])
    predictions = model.predict(dtest)
    score = r2_score(y_test, predictions)
    print('\tScore {0}\n\n'.format(score))
    
    return {'loss': -score, 'params': params, 'status': STATUS_OK}

# %%
def optimize(trials):
    space = {
        'n_estimators': hp.quniform("n_estimators", 100, 2000, 10),
        'num_round': 100,
        'learning_rate': hp.quniform("eta", 0.005, 0.05, 0.005),
        'max_depth': hp.quniform("max_depth", 10, 15, 1),
        'min_child_weight': hp.quniform("min_child_weight", 1, 15, 1),
        'subsample': hp.quniform("subsample", 0.5, 1, 0.05),
        'gamma': hp.quniform("gamma", 0.5, 1, 0.01),
        'colsample_bytree': hp.quniform("colsample_bytree", 0.4, 1, 0.05),
        'nthread': 4,
        'silent': 1,
    }

    best = fmin(score, space, algo=tpe.suggest, trials=trials, max_evals=100)
    return best

# %%
trials = Trials()
best_params = optimize(trials)
best_params
# Out:
# Params:
# {'colsample_bytree': 0.55, 'gamma': 0.98, 'learning_rate': 0.03, 'max_depth': 12.0, 'min_child_weight': 8.0, 'n_estimators': 1800.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.65}
# [22:36:48] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.86418503960255
#
#
# Params:
# {'colsample_bytree': 0.4, 'gamma': 0.97, 'learning_rate': 0.03, 'max_depth': 11.0, 'min_child_weight': 14.0, 'n_estimators': 960.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.6000000000000001}
# [22:36:49] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8474976713087123
#
#
# Params:
# {'colsample_bytree': 0.5, 'gamma': 0.9, 'learning_rate': 0.025, 'max_depth': 13.0, 'min_child_weight': 4.0, 'n_estimators': 540.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.5}
# [22:36:49] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8497183905983907
#
#
# Params:
# {'colsample_bytree': 0.75, 'gamma': 0.97, 'learning_rate': 0.035, 'max_depth': 14.0, 'min_child_weight': 11.0, 'n_estimators': 400.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.9500000000000001}
# [22:36:50] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8913829779833494
#
#
# Params:
# {'colsample_bytree': 0.8, 'gamma': 0.96, 'learning_rate': 0.03, 'max_depth': 15.0, 'min_child_weight': 5.0, 'n_estimators': 290.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.65}
# [22:36:50] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8865890890937682
#
#
# Params:
# {'colsample_bytree': 0.9, 'gamma': 0.64, 'learning_rate': 0.02, 'max_depth': 14.0, 'min_child_weight': 9.0, 'n_estimators': 630.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.8}
# [22:36:51] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8543211512919817
#
#
# Params:
# {'colsample_bytree': 0.45, 'gamma': 0.53, 'learning_rate': 0.035, 'max_depth': 13.0, 'min_child_weight': 12.0, 'n_estimators': 1630.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.8}
# [22:36:52] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.874964797799616
#
#
# Params:
# {'colsample_bytree': 0.45, 'gamma': 0.53, 'learning_rate': 0.03, 'max_depth': 11.0, 'min_child_weight': 2.0, 'n_estimators': 1690.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.8500000000000001}
# [22:36:52] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.861843721950385
#
#
# Params:
# {'colsample_bytree': 0.45, 'gamma': 0.85, 'learning_rate': 0.025, 'max_depth': 13.0, 'min_child_weight': 4.0, 'n_estimators': 1380.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.75}
# [22:36:52] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8502395332056683
#
#
# Params:
# {'colsample_bytree': 0.5, 'gamma': 0.85, 'learning_rate': 0.02, 'max_depth': 14.0, 'min_child_weight': 12.0, 'n_estimators': 280.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.7000000000000001}
# [22:36:53] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8171857710639285
#
#
# Params:
# {'colsample_bytree': 0.55, 'gamma': 0.84, 'learning_rate': 0.035, 'max_depth': 12.0, 'min_child_weight': 7.0, 'n_estimators': 1340.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.8500000000000001}
# [22:36:53] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.875356031662994
#
#
# Params:
# {'colsample_bytree': 0.55, 'gamma': 0.79, 'learning_rate': 0.035, 'max_depth': 15.0, 'min_child_weight': 11.0, 'n_estimators': 520.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.7000000000000001}
# [22:36:54] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8735412728943327
#
#
# Params:
# {'colsample_bytree': 0.55, 'gamma': 0.9400000000000001, 'learning_rate': 0.03, 'max_depth': 14.0, 'min_child_weight': 15.0, 'n_estimators': 890.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.8500000000000001}
# [22:36:55] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8627535458393532
#
#
# Params:
# {'colsample_bytree': 1.0, 'gamma': 0.65, 'learning_rate': 0.03, 'max_depth': 12.0, 'min_child_weight': 12.0, 'n_estimators': 990.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.55}
# [22:36:55] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8770576810350804
#
#
# Params:
# {'colsample_bytree': 0.5, 'gamma': 0.91, 'learning_rate': 0.015, 'max_depth': 15.0, 'min_child_weight': 8.0, 'n_estimators': 1710.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.65}
# [22:36:55] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.7601111782071148
#
#
# Params:
# {'colsample_bytree': 0.6000000000000001, 'gamma': 0.62, 'learning_rate': 0.02, 'max_depth': 12.0, 'min_child_weight': 3.0, 'n_estimators': 1910.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.7000000000000001}
# [22:36:56] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8477765124089057
#
#
# Params:
# {'colsample_bytree': 0.6000000000000001, 'gamma': 0.61, 'learning_rate': 0.02, 'max_depth': 12.0, 'min_child_weight': 15.0, 'n_estimators': 1540.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.7000000000000001}
# [22:36:56] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8365271991879007
#
#
# Params:
# {'colsample_bytree': 0.9, 'gamma': 0.76, 'learning_rate': 0.015, 'max_depth': 13.0, 'min_child_weight': 12.0, 'n_estimators': 1500.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.9}
# [22:36:57] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8065913517829707
#
#
# Params:
# {'colsample_bytree': 0.55, 'gamma': 0.76, 'learning_rate': 0.005, 'max_depth': 12.0, 'min_child_weight': 4.0, 'n_estimators': 1310.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.65}
# [22:36:57] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.3294929624519718
#
#
# Params:
# {'colsample_bytree': 0.8, 'gamma': 0.96, 'learning_rate': 0.045, 'max_depth': 14.0, 'min_child_weight': 7.0, 'n_estimators': 1020.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.65}
# [22:36:58] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8942792274681057
#
#
# Params:
# {'colsample_bytree': 0.75, 'gamma': 1.0, 'learning_rate': 0.05, 'max_depth': 14.0, 'min_child_weight': 10.0, 'n_estimators': 780.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 1.0}
# [22:36:58] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8936402295587849
#
#
# Params:
# {'colsample_bytree': 0.7000000000000001, 'gamma': 0.91, 'learning_rate': 0.05, 'max_depth': 14.0, 'min_child_weight': 6.0, 'n_estimators': 760.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 1.0}
# [22:36:59] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8921441755047609
#
#
# Params:
# {'colsample_bytree': 0.8500000000000001, 'gamma': 0.6900000000000001, 'learning_rate': 0.05, 'max_depth': 15.0, 'min_child_weight': 10.0, 'n_estimators': 1170.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.5}
# [22:37:00] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8902702272638888
#
#
# Params:
# {'colsample_bytree': 0.7000000000000001, 'gamma': 0.99, 'learning_rate': 0.045, 'max_depth': 14.0, 'min_child_weight': 6.0, 'n_estimators': 1140.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.55}
# [22:37:01] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8921612749352151
#
#
# Params:
# {'colsample_bytree': 1.0, 'gamma': 0.81, 'learning_rate': 0.045, 'max_depth': 10.0, 'min_child_weight': 9.0, 'n_estimators': 760.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.9500000000000001}
# [22:37:01] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8812563748639057
#
#
# Params:
# {'colsample_bytree': 0.8, 'gamma': 1.0, 'learning_rate': 0.045, 'max_depth': 15.0, 'min_child_weight': 7.0, 'n_estimators': 100.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.6000000000000001}
# [22:37:02] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8945137511236653
#
#
# Params:
# {'colsample_bytree': 0.9, 'gamma': 0.7000000000000001, 'learning_rate': 0.045, 'max_depth': 15.0, 'min_child_weight': 7.0, 'n_estimators': 240.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.55}
# [22:37:02] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8970709737633182
#
#
# Params:
# {'colsample_bytree': 0.9500000000000001, 'gamma': 0.71, 'learning_rate': 0.04, 'max_depth': 15.0, 'min_child_weight': 6.0, 'n_estimators': 110.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.55}
# [22:37:03] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8966338233713459
#
#
# Params:
# {'colsample_bytree': 0.9500000000000001, 'gamma': 0.71, 'learning_rate': 0.04, 'max_depth': 15.0, 'min_child_weight': 2.0, 'n_estimators': 120.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.55}
# [22:37:03] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8936378979522785
#
#
# Params:
# {'colsample_bytree': 0.9500000000000001, 'gamma': 0.58, 'learning_rate': 0.04, 'max_depth': 11.0, 'min_child_weight': 6.0, 'n_estimators': 220.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.6000000000000001}
# [22:37:05] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8905601509754736
#
#
# Params:
# {'colsample_bytree': 0.9500000000000001, 'gamma': 0.72, 'learning_rate': 0.04, 'max_depth': 15.0, 'min_child_weight': 5.0, 'n_estimators': 380.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.5}
# [22:37:06] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8946896383099444
#
#
# Params:
# {'colsample_bytree': 0.9, 'gamma': 0.68, 'learning_rate': 0.04, 'max_depth': 10.0, 'min_child_weight': 8.0, 'n_estimators': 120.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.55}
# [22:37:08] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8896726038577313
#
#
# Params:
# {'colsample_bytree': 0.8500000000000001, 'gamma': 0.58, 'learning_rate': 0.05, 'max_depth': 13.0, 'min_child_weight': 3.0, 'n_estimators': 550.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.5}
# [22:37:09] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8959216728234202
#
#
# Params:
# {'colsample_bytree': 1.0, 'gamma': 0.74, 'learning_rate': 0.045, 'max_depth': 15.0, 'min_child_weight': 1.0, 'n_estimators': 400.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.6000000000000001}
# [22:37:10] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8893181457110866
#
#
# Params:
# {'colsample_bytree': 0.8500000000000001, 'gamma': 0.67, 'learning_rate': 0.035, 'max_depth': 15.0, 'min_child_weight': 9.0, 'n_estimators': 220.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.6000000000000001}
# [22:37:13] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8889072218083519
#
#
# Params:
# {'colsample_bytree': 0.75, 'gamma': 0.79, 'learning_rate': 0.04, 'max_depth': 13.0, 'min_child_weight': 5.0, 'n_estimators': 640.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.75}
# [22:37:14] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8923668296370526
#
#
# Params:
# {'colsample_bytree': 0.65, 'gamma': 0.55, 'learning_rate': 0.005, 'max_depth': 14.0, 'min_child_weight': 7.0, 'n_estimators': 430.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.55}
# [22:37:15] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.36143990097298584
#
#
# Params:
# {'colsample_bytree': 0.9500000000000001, 'gamma': 0.71, 'learning_rate': 0.025, 'max_depth': 11.0, 'min_child_weight': 4.0, 'n_estimators': 890.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.5}
# [22:37:16] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8727061120614221
#
#
# Params:
# {'colsample_bytree': 0.9, 'gamma': 0.87, 'learning_rate': 0.045, 'max_depth': 15.0, 'min_child_weight': 5.0, 'n_estimators': 250.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.6000000000000001}
# [22:37:17] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8944114978170572
#
#
# Params:
# {'colsample_bytree': 0.8500000000000001, 'gamma': 0.65, 'learning_rate': 0.035, 'max_depth': 14.0, 'min_child_weight': 13.0, 'n_estimators': 520.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.8}
# [22:37:19] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8896012503060688
#
#
# Params:
# {'colsample_bytree': 0.8, 'gamma': 0.8200000000000001, 'learning_rate': 0.05, 'max_depth': 13.0, 'min_child_weight': 10.0, 'n_estimators': 640.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.65}
# [22:37:20] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8974111375221718
#
#
# Params:
# {'colsample_bytree': 0.75, 'gamma': 0.8200000000000001, 'learning_rate': 0.05, 'max_depth': 11.0, 'min_child_weight': 14.0, 'n_estimators': 590.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.75}
# [22:37:21] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8907246872631596
#
#
# Params:
# {'colsample_bytree': 0.8, 'gamma': 0.88, 'learning_rate': 0.05, 'max_depth': 13.0, 'min_child_weight': 10.0, 'n_estimators': 680.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.7000000000000001}
# [22:37:22] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8953671815930965
#
#
# Params:
# {'colsample_bytree': 0.65, 'gamma': 0.79, 'learning_rate': 0.015, 'max_depth': 10.0, 'min_child_weight': 11.0, 'n_estimators': 870.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.65}
# [22:37:23] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.789216807393101
#
#
# Params:
# {'colsample_bytree': 0.65, 'gamma': 0.74, 'learning_rate': 0.025, 'max_depth': 12.0, 'min_child_weight': 9.0, 'n_estimators': 320.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.8}
# [22:37:24] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8751280801352187
#
#
# Params:
# {'colsample_bytree': 0.8, 'gamma': 0.9400000000000001, 'learning_rate': 0.01, 'max_depth': 13.0, 'min_child_weight': 8.0, 'n_estimators': 1100.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.65}
# [22:37:25] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.6767967488317785
#
#
# Params:
# {'colsample_bytree': 0.75, 'gamma': 0.8300000000000001, 'learning_rate': 0.03, 'max_depth': 13.0, 'min_child_weight': 11.0, 'n_estimators': 1240.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.75}
# [22:37:26] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8837656960267166
#
#
# Params:
# {'colsample_bytree': 0.9, 'gamma': 0.88, 'learning_rate': 0.035, 'max_depth': 11.0, 'min_child_weight': 13.0, 'n_estimators': 450.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.7000000000000001}
# [22:37:27] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8857279541165823
#
#
# Params:
# {'colsample_bytree': 0.7000000000000001, 'gamma': 0.78, 'learning_rate': 0.045, 'max_depth': 12.0, 'min_child_weight': 13.0, 'n_estimators': 340.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.6000000000000001}
# [22:37:29] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8836158766993554
#
#
# Params:
# {'colsample_bytree': 0.4, 'gamma': 0.85, 'learning_rate': 0.05, 'max_depth': 14.0, 'min_child_weight': 10.0, 'n_estimators': 680.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.5}
# [22:37:29] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8749193805766009
#
#
# Params:
# {'colsample_bytree': 1.0, 'gamma': 0.63, 'learning_rate': 0.03, 'max_depth': 11.0, 'min_child_weight': 11.0, 'n_estimators': 490.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.9}
# [22:37:30] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8808398352678299
#
#
# Params:
# {'colsample_bytree': 0.6000000000000001, 'gamma': 0.61, 'learning_rate': 0.045, 'max_depth': 13.0, 'min_child_weight': 14.0, 'n_estimators': 1860.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.7000000000000001}
# [22:37:32] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8887695799476412
#
#
# Params:
# {'colsample_bytree': 0.8500000000000001, 'gamma': 0.81, 'learning_rate': 0.035, 'max_depth': 12.0, 'min_child_weight': 7.0, 'n_estimators': 810.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.8}
# [22:37:33] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8914110438083904
#
#
# Params:
# {'colsample_bytree': 0.8, 'gamma': 0.93, 'learning_rate': 0.025, 'max_depth': 10.0, 'min_child_weight': 9.0, 'n_estimators': 180.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.65}
# [22:37:34] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.869861504266562
#
#
# Params:
# {'colsample_bytree': 0.9, 'gamma': 0.77, 'learning_rate': 0.01, 'max_depth': 14.0, 'min_child_weight': 3.0, 'n_estimators': 1070.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.65}
# [22:37:35] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.6820493762742132
#
#
# Params:
# {'colsample_bytree': 0.75, 'gamma': 0.5, 'learning_rate': 0.05, 'max_depth': 13.0, 'min_child_weight': 12.0, 'n_estimators': 950.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.55}
# [22:37:36] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8840533135197166
#
#
# Params:
# {'colsample_bytree': 0.7000000000000001, 'gamma': 0.74, 'learning_rate': 0.04, 'max_depth': 14.0, 'min_child_weight': 8.0, 'n_estimators': 700.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.8500000000000001}
# [22:37:37] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8929134308022318
#
#
# Params:
# {'colsample_bytree': 0.8500000000000001, 'gamma': 0.67, 'learning_rate': 0.035, 'max_depth': 12.0, 'min_child_weight': 15.0, 'n_estimators': 1490.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.75}
# [22:37:38] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8859074279289643
#
#
# Params:
# {'colsample_bytree': 0.8, 'gamma': 0.51, 'learning_rate': 0.02, 'max_depth': 13.0, 'min_child_weight': 10.0, 'n_estimators': 960.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.6000000000000001}
# [22:37:39] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8484533687412044
#
#
# Params:
# {'colsample_bytree': 1.0, 'gamma': 0.97, 'learning_rate': 0.045, 'max_depth': 14.0, 'min_child_weight': 1.0, 'n_estimators': 580.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.7000000000000001}
# [22:37:40] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8899634349044893
#
#
# Params:
# {'colsample_bytree': 0.65, 'gamma': 0.56, 'learning_rate': 0.04, 'max_depth': 15.0, 'min_child_weight': 6.0, 'n_estimators': 1990.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.5}
# [22:37:42] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8883353760749094
#
#
# Params:
# {'colsample_bytree': 0.9, 'gamma': 0.9, 'learning_rate': 0.05, 'max_depth': 14.0, 'min_child_weight': 2.0, 'n_estimators': 170.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.55}
# [22:37:44] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8957124343657601
#
#
# Params:
# {'colsample_bytree': 0.9500000000000001, 'gamma': 0.86, 'learning_rate': 0.03, 'max_depth': 10.0, 'min_child_weight': 7.0, 'n_estimators': 310.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.6000000000000001}
# [22:37:45] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
# ...
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8875791005427229
#
#
# Params:
# {'colsample_bytree': 0.8, 'gamma': 0.7000000000000001, 'learning_rate': 0.045, 'max_depth': 14.0, 'min_child_weight': 10.0, 'n_estimators': 540.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.8}
# [22:38:03] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8951757216417675
#
#
# Params:
# {'colsample_bytree': 0.7000000000000001, 'gamma': 0.8300000000000001, 'learning_rate': 0.015, 'max_depth': 12.0, 'min_child_weight': 8.0, 'n_estimators': 1320.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.65}
# [22:38:04] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.7940249506634409
#
#
# Params:
# {'colsample_bytree': 0.65, 'gamma': 0.75, 'learning_rate': 0.01, 'max_depth': 13.0, 'min_child_weight': 7.0, 'n_estimators': 1000.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.6000000000000001}
# [22:38:04] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.6645936375464698
#
#
# Params:
# {'colsample_bytree': 0.8500000000000001, 'gamma': 0.67, 'learning_rate': 0.05, 'max_depth': 15.0, 'min_child_weight': 10.0, 'n_estimators': 640.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.7000000000000001}
# [22:38:05] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8958665397566752
#
#
# Params:
# {'colsample_bytree': 0.9, 'gamma': 0.5700000000000001, 'learning_rate': 0.045, 'max_depth': 14.0, 'min_child_weight': 12.0, 'n_estimators': 490.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.65}
# [22:38:05] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8923780268421792
#
#
# Params:
# {'colsample_bytree': 0.75, 'gamma': 0.64, 'learning_rate': 0.025, 'max_depth': 15.0, 'min_child_weight': 13.0, 'n_estimators': 830.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.75}
# [22:38:06] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8717987761355058
#
#
# Params:
# {'colsample_bytree': 0.8, 'gamma': 0.84, 'learning_rate': 0.035, 'max_depth': 13.0, 'min_child_weight': 9.0, 'n_estimators': 740.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.55}
# [22:38:06] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8901049834923075
#
#
# Params:
# {'colsample_bytree': 1.0, 'gamma': 0.78, 'learning_rate': 0.02, 'max_depth': 11.0, 'min_child_weight': 3.0, 'n_estimators': 920.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.8500000000000001}
# [22:38:07] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.846726262954998
#
#
# Params:
# {'colsample_bytree': 0.8500000000000001, 'gamma': 0.9, 'learning_rate': 0.04, 'max_depth': 13.0, 'min_child_weight': 11.0, 'n_estimators': 1100.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.5}
# [22:38:07] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8837840031831039
#
#
# Params:
# {'colsample_bytree': 0.45, 'gamma': 0.73, 'learning_rate': 0.05, 'max_depth': 15.0, 'min_child_weight': 7.0, 'n_estimators': 1240.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.6000000000000001}
# [22:38:08] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8848906299621292
#
#
# Params:
# {'colsample_bytree': 0.9500000000000001, 'gamma': 0.62, 'learning_rate': 0.045, 'max_depth': 14.0, 'min_child_weight': 9.0, 'n_estimators': 420.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.8}
# [22:38:08] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8963525631746824
#
#
# Params:
# {'colsample_bytree': 0.7000000000000001, 'gamma': 0.92, 'learning_rate': 0.03, 'max_depth': 12.0, 'min_child_weight': 12.0, 'n_estimators': 1590.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.65}
# [22:38:09] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8793664376589247
#
#
# Params:
# {'colsample_bytree': 0.8, 'gamma': 0.66, 'learning_rate': 0.05, 'max_depth': 14.0, 'min_child_weight': 8.0, 'n_estimators': 240.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.9500000000000001}
# [22:38:09] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8948096125265231
#
#
# Params:
# {'colsample_bytree': 0.65, 'gamma': 0.52, 'learning_rate': 0.035, 'max_depth': 12.0, 'min_child_weight': 7.0, 'n_estimators': 580.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.55}
# [22:38:10] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8853584989645041
#
#
# Params:
# {'colsample_bytree': 0.6000000000000001, 'gamma': 0.88, 'learning_rate': 0.04, 'max_depth': 11.0, 'min_child_weight': 5.0, 'n_estimators': 1380.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.75}
# [22:38:10] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8924023085830007
#
#
# Params:
# {'colsample_bytree': 0.9, 'gamma': 0.7000000000000001, 'learning_rate': 0.045, 'max_depth': 10.0, 'min_child_weight': 6.0, 'n_estimators': 710.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.7000000000000001}
# [22:38:11] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8920349230036392
#
#
# Params:
# {'colsample_bytree': 0.75, 'gamma': 0.75, 'learning_rate': 0.05, 'max_depth': 15.0, 'min_child_weight': 10.0, 'n_estimators': 350.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.5}
# [22:38:11] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8869703919831914
#
#
# Params:
# {'colsample_bytree': 0.55, 'gamma': 0.59, 'learning_rate': 0.005, 'max_depth': 13.0, 'min_child_weight': 8.0, 'n_estimators': 770.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.6000000000000001}
# [22:38:12] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.3251474246415791
#
#
# Params:
# {'colsample_bytree': 0.8500000000000001, 'gamma': 0.8200000000000001, 'learning_rate': 0.03, 'max_depth': 14.0, 'min_child_weight': 4.0, 'n_estimators': 680.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.65}
# [22:38:12] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8873427755044396
#
#
# Params:
# {'colsample_bytree': 0.8, 'gamma': 0.86, 'learning_rate': 0.04, 'max_depth': 15.0, 'min_child_weight': 11.0, 'n_estimators': 1150.0, 'nthread': 4, 'num_round': 100, 'silent': 1, 'subsample': 0.55}
# [22:38:13] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, num_round, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 	Score 0.8885260256475179
#
#
# 100%|██████████| 100/100 [01:25<00:00,  1.17trial/s, best loss: -0.8974111375221718]
# {'colsample_bytree': 0.8,
#  'eta': 0.05,
#  'gamma': 0.8200000000000001,
#  'max_depth': 13.0,
#  'min_child_weight': 10.0,
#  'n_estimators': 640.0,
#  'subsample': 0.65}

# %%
best_params['max_depth'] = int(best_params['max_depth'])
best_params["nthread"] = 4
best_params["silent"] = 1

# %%
dtrain = xgb.DMatrix(X_train, y_train)

# %%
# %%time
xgbCvResult = xgb.cv(
    best_params, dtrain, num_boost_round=500, nfold=3, early_stopping_rounds=70
)
# Out:
# [14:45:45] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:45:45] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:45:45] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Wall time: 1.38 s

# %%
xgbCvResult
# Out:
#      train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0          44.394937        0.775164       44.434169       1.563418
# 1          43.014975        0.759026       43.128663       1.504606
# 2          41.669143        0.741812       41.849395       1.459798
# 3          40.413803        0.692407       40.644402       1.439471
# 4          39.237672        0.628009       39.541808       1.433555
# ..               ...             ...             ...            ...
# 115        10.906838        0.258345       19.535421       0.761877
# 116        10.855468        0.257736       19.531232       0.757859
# 117        10.806407        0.268461       19.518159       0.754961
# 118        10.764405        0.271894       19.518489       0.745260
# 119        10.732844        0.274008       19.516985       0.748169
#
# [120 rows x 4 columns]

# %%
plt.plot(range(xgbCvResult.shape[0]), xgbCvResult["test-rmse-mean"], label='test')
plt.plot(range(xgbCvResult.shape[0]), xgbCvResult["train-rmse-mean"], label='train');
plt.legend()

# %%
best_num_round = np.argmin(xgbCvResult["test-rmse-mean"])
best_num_round
# Out:
# 119

# %%
def df_results(hp_results):
    """
    Отображаем результаты hyperopt в формате DataFrame 

    :hp_results: результаты hyperop
    :return: pandas DataFrame
    """ 

    results = pd.DataFrame([{**x, **x['params']} for x in  hp_results])
    results['loss'] = abs(results['loss'])
    results.drop(labels=['status', 'params'], axis=1, inplace=True)
    results.sort_values(by=['loss'], ascending=False, inplace=True)
    return results

results = df_results(trials.results)

# %%
bestXGB = xgb.train(best_params, dtrain, best_num_round)
# Out:
# [14:45:47] WARNING: ..\src\learner.cc:541:
# Parameters: { n_estimators, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.

# %%
dtest = xgb.DMatrix(X_test)

# %%
XGBpred = bestXGB.predict(dtest)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16640/1643840132.py in <module>
# ----> 1 XGBpred = bestXGB.predict(dtest)
#
# NameError: name 'bestXGB' is not defined

# %%
mean_absolute_error(y_test, XGBpred), r2_score(y_test, XGBpred)
# Out:
# (8.409643606320325, 0.7441659892035416)

# %%
import pickle

# %%
# pkl_filename = 'xgb_oil.pkl'
# with open(pkl_filename, 'wb') as file:
#     pickle.dump(bestXGB, file)

# %%
with open('xgb_water.pkl', 'rb') as file:
    model = pickle.load(file)

# %%
from sklearn.metrics import mean_absolute_percentage_error

# %%
XGBpred = model.predict(dtest)

# %%
mean_absolute_percentage_error(y_test, XGBpred)
# Out:
# 5196116060981659.0

# %%
xgb.plot_importance(bestXGB)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
plt.figure(figsize=(7, 5))
plt.scatter(y_test, XGBpred, alpha=.7);
plt.plot([0, y_test.max()], [0, y_test.max()], 'r--');
plt.xlabel('Замер воды на сепараторе, $м^3$')
plt.ylabel('Рассчитанный дебит воды, $м^3$')
plt.xlim(left=0)
plt.ylim(bottom=0)
# Out:
# (0.0, 509.84288896836324)

# %%
plt.figure(figsize=(15, 9))
plt.plot(y_test[1500:], color='orange', alpha=1, label='Actual Rate')
plt.plot(XGBpred[1500:], color='blue', alpha=.7, label='Predicted Rate')
plt.legend(loc='best')
plt.ylabel('Rate')
plt.grid()

# %%
# Ns = X.shape[0]     # Number of sequences
# Nif = X.shape[1]    # Number of input features
# Nof = y_all.shape[1]    # Number of output features

# X_plot = pd.DataFrame(MinMaxScaler().fit_transform(X))
# y_plot = pd.DataFrame(MinMaxScaler().fit_transform(y_all))
# squeeze = 0.9
# barheight = squeeze * np.minimum(1 / Ns, 0.1)
# interbar = 0.1 * barheight
# starty = 0.5 + (barheight + interbar) * Ns / 2

# f, ax = plt.subplots(1, sharex=True)
# plt.xlim(0, 1)   # Fix the x range to (0, 1)

# for i in range(Ns):
#     for j in range(Nif):
#         ax.plot(X_plot.iloc[i:].index, X_plot.iloc[i:, j], 'b')
#     for j in range(Nof):
#         ax.plot(y_plot.iloc[i:].index, y_plot.iloc[i:, j], 'r')

# startybar = starty
# for i in range(Ns):
#     endybar = startybar - barheight
#     ax.axhspan(startybar, endybar, xmin=min(X_plot.iloc[i:].index), xmax=max(X_plot.iloc[i:].index), facecolor='g', alpha=0.5)  # Input
#     ax.axhspan(startybar, endybar, xmin=min(y_plot.iloc[i:].index), xmax=max(y_plot.iloc[i:].index), facecolor='r', alpha=0.5)  # Output
#     startybar = endybar - interbar
